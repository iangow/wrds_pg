# %%
from wrds2pg import get_process

sas_code = "proc contents data=reprisk.v2_risk_incidents; run;"
p = get_process(sas_code, wrds_id="iangow")
contents = p.readlines()
contents
# Out:
# ['                                 The SAS System                                1\n',
#  '                                              Thursday, May 18, 2023 10:39:00 AM\n',
#  '\n',
#  '                             The CONTENTS Procedure\n',
#  '\n',
#  'Data Set Name        REPRISK.V2_RISK_INCIDENTS     Observations           808981\n',
#  'Member Type          DATA                          Variables              125   \n',
#  'Engine               V9                            Indexes                3     \n',
#  'Created              03/14/2023 21:49:22           Observation Length     1629  \n',
#  'Last Modified        03/14/2023 21:49:25           Deleted Observations   0     \n',
#  'Protection                                         Compressed             CHAR  \n',
#  'Data Set Type                                      Reuse Space            NO    \n',
#  'Label                Reprisk V2 risk               Point to Observations  YES   \n',
# ...
